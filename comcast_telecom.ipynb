# %% [markdown]
# #### import relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# #### storing dataset into raw_data

# %%
raw_data= pd.read_csv('Comcast_telecom_complaints_data.csv')

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
# Ticket #                       2224 non-null object
# Customer Complaint             2224 non-null object
# Date                           2224 non-null object
# Date_month_year                2224 non-null object
# Time                           2224 non-null object
# Received Via                   2224 non-null object
# City                           2224 non-null object
# State                          2224 non-null object
# Zip code                       2224 non-null int64
# Status                         2224 non-null object
# Filing on Behalf of Someone    2224 non-null object
# dtypes: int64(1), object(10)
# memory usage: 191.2+ KB

# %% [markdown]
# #### convert 'Date_month_year' column to datetime format from object

# %%
raw_data['Date_month_year']=pd.to_datetime(raw_data['Date_month_year'])

# %%
raw_data=raw_data.set_index('Date_month_year')

# %%
raw_data.head()
# Out:
#                 Ticket #                                 Customer Complaint  \
# Date_month_year
# 2015-04-22        250635                      Comcast Cable Internet Speeds
# 2015-08-04        223441       Payment disappear - service got disconnected
# 2015-04-18        242732                                  Speed and Service
# 2015-07-05        277946  Comcast Imposed a New Usage Cap of 300GB that ...
# 2015-05-26        307175         Comcast not working and no service to boot
#
#                      Date         Time        Received Via      City  \
# Date_month_year
# 2015-04-22       22-04-15   3:53:50 PM  Customer Care Call  Abingdon
# 2015-08-04       04-08-15  10:22:56 AM            Internet   Acworth
# 2015-04-18       18-04-15   9:55:47 AM            Internet   Acworth
# 2015-07-05       05-07-15  11:59:35 AM            Internet   Acworth
# 2015-05-26       26-05-15   1:25:26 PM            Internet   Acworth
#
#                     State  Zip code  Status Filing on Behalf of Someone
# Date_month_year
# 2015-04-22       Maryland     21009  Closed                          No
# 2015-08-04        Georgia     30102  Closed                          No
# 2015-04-18        Georgia     30101  Closed                         Yes
# 2015-07-05        Georgia     30101    Open                         Yes
# 2015-05-26        Georgia     30101  Solved                          No

# %% [markdown]
# #### dropping irrelevant columns

# %%
data= raw_data.drop(['Ticket #','Time'], axis=1)

# %%
data= data.sort_values(by='Date')

# %%
data.head()
# Out:
#                                                Customer Complaint      Date  \
# Date_month_year
# 2015-01-04       Fraudulent claims reported to collections agency  04-01-15
# 2015-01-04                             Comcast refusal of service  04-01-15
# 2015-01-04                                          Comcast Cable  04-01-15
# 2015-01-04                                          Data Overages  04-01-15
# 2015-01-04                                                Comcast  04-01-15
#
#                        Received Via              City         State  Zip code  \
# Date_month_year
# 2015-01-04       Customer Care Call           Atlanta       Georgia     30312
# 2015-01-04       Customer Care Call             Wayne  Pennsylvania     19087
# 2015-01-04                 Internet          Franklin     Tennessee     37067
# 2015-01-04                 Internet          Savannah       Georgia     31406
# 2015-01-04                 Internet  North Huntingdon  Pennsylvania     15642
#
#                  Status Filing on Behalf of Someone
# Date_month_year
# 2015-01-04       Closed                          No
# 2015-01-04       Closed                          No
# 2015-01-04       Closed                          No
# 2015-01-04       Closed                          No
# 2015-01-04       Closed                          No

# %%
data['Date']=pd.to_datetime(data['Date'])

# %% [markdown]
# #### dataframe for number of complaints by day

# %%
data['Date'].value_counts(dropna=False)[:8]
# Out:
# 2015-06-24    218
# 2015-06-23    190
# 2015-06-25     98
# 2015-06-26     55
# 2015-06-30     53
# 2015-06-29     51
# 2015-06-18     47
# 2015-06-12     43
# Name: Date, dtype: int64

# %%
data['Date'].value_counts().plot()

# %% [markdown]
# #### grouping number of complaints wrt month

# %%
months= data.groupby(pd.Grouper(freq="M")).size().plot()

# %% [markdown]
# #### viewing customer complaints based on categories

# %%
data['Customer Complaint'].value_counts(dropna=False)[:9]
# Out:
# Comcast                     83
# Comcast Internet            18
# Comcast Data Cap            17
# comcast                     13
# Comcast Data Caps           11
# Comcast Billing             11
# Data Caps                   11
# Unfair Billing Practices     9
# Comcast data caps            8
# Name: Customer Complaint, dtype: int64

# %%
data['Customer Complaint'].value_counts(dropna=False)[:9].plot.bar()

# %% [markdown]
# #### assigning pending to open and solved to close

# %%
data["newStatus"] = ["Open" if Status=="Open" or Status=="Pending" else "Closed" for Status in data["Status"]]
data.drop(['Status'],axis=1)
# Out:
#                                                 Customer Complaint       Date  \
# Date_month_year
# 2015-01-04        Fraudulent claims reported to collections agency 2015-04-01
# 2015-01-04                              Comcast refusal of service 2015-04-01
# 2015-01-04                                           Comcast Cable 2015-04-01
# 2015-01-04                                           Data Overages 2015-04-01
# 2015-01-04                                                 Comcast 2015-04-01
# 2015-01-04                                      Comcast harassment 2015-04-01
# 2015-01-04       Comcast is ignoring me now. They are making NO... 2015-04-01
# 2015-01-04       Unable to get in touch with anyone that has th... 2015-04-01
# 2015-01-04             Comcast Lied About Pricing And Installation 2015-04-01
# 2015-01-04                                             overcharged 2015-04-01
# 2015-01-04                                     No Internet service 2015-04-01
# 2015-01-04          Comcast Customer Service; Theft; Inconsistency 2015-04-01
# 2015-01-04                                       Incorrect Billing 2015-04-01
# 2015-01-04                                           comcast cable 2015-04-01
# 2015-01-04       Comcast speeds as low as 12 MB/s, paying for 1... 2015-04-01
# 2015-01-04                                        Horrible Service 2015-04-01
# 2015-01-04                                                 billing 2015-04-01
# 2015-01-04                                      Fradulent Services 2015-04-01
# 2015-02-04          Comcast Terrible Experience with no resolution 2015-04-02
# 2015-02-04          Comcast Terrible Experience with no resolution 2015-04-02
# 2015-02-04       Xfinity/Comcast throttles bandwidth way below ... 2015-04-02
# 2015-02-04       Comcast (Xfinity); Larger withdrawal on automa... 2015-04-02
# 2015-02-04                        HBO GO blocked on Amazon Fire TV 2015-04-02
# 2015-02-04                       Internet Provider Data Thresholds 2015-04-02
# 2015-02-04                                      Comcast run around 2015-04-02
# 2015-02-04             Consistent speed/connectivity with internet 2015-04-02
# 2015-02-04                                                 comcast 2015-04-02
# 2015-02-04                                 Data usage with Comcast 2015-04-02
# 2015-02-04                        Huge number of lies from Comcast 2015-04-02
# 2015-02-04                 COMCAST THROTTLING SPEEDS AND DATA CAPS 2015-04-02
# ...                                                            ...        ...
# 2015-02-04       Customer Care Call           Suwanee        Georgia
# 2015-02-04       Customer Care Call      Philadelphia   Pennsylvania
# 2015-02-04                 Internet           Bothell     Washington
# 2015-02-04                 Internet          Franklin      Tennessee
# 2015-02-04                 Internet          Sheridan       Colorado
# 2015-02-04       Customer Care Call        Gold River     California
# 2015-02-04                 Internet    Peachtree City        Georgia
# 2015-02-04                 Internet             Rydal        Georgia
# 2015-02-04       Customer Care Call          Santa Fe     New Mexico
# 2015-02-04                 Internet           Chicago       Illinois
# ...                             ...               ...            ...
# 2015-06-30       Customer Care Call       Santa Clara     California
# 2015-06-30                 Internet          Voorhees     New Jersey
# 2015-06-30       Customer Care Call          St. Paul      Minnesota
# 2015-06-30       Customer Care Call    Atlantic Beach        Florida
# 2015-06-30       Customer Care Call          Portland         Oregon
# 2015-06-30                 Internet           Atlanta        Georgia
# 2015-06-30                 Internet           Lilburn        Georgia
# 2015-06-30       Customer Care Call            Dallas        Georgia
# 2015-06-30       Customer Care Call               Slc           Utah
# 2015-06-30                 Internet          Norcross        Georgia
# 2015-06-30       Customer Care Call            Dacula        Georgia
# 2015-06-30                 Internet           Chicago       Illinois
# 2015-06-30                 Internet           Atlanta        Georgia
# 2015-06-30       Customer Care Call           Chicago       Illinois
# 2015-06-30       Customer Care Call             Jesup        Georgia
# 2015-06-30                 Internet       West Monroe      Louisiana
# 2015-06-30                 Internet            Tupelo    Mississippi
# 2015-06-30                 Internet            Senoia        Georgia
# 2015-06-30                 Internet          Fountain       Colorado
# 2015-06-30                 Internet          Hatfield   Pennsylvania
# 2015-05-31                 Internet           Houston          Texas
# 2015-05-31       Customer Care Call            Duluth        Georgia
# 2015-05-31       Customer Care Call  Colorado Springs       Colorado
# 2015-05-31                 Internet             Evans        Georgia
# 2015-05-31       Customer Care Call         Camp Hill   Pennsylvania
# 2015-05-31       Customer Care Call         Beaverton         Oregon
# 2015-05-31                 Internet      East Windsor     New Jersey
# 2015-05-31                 Internet        Loganville        Georgia
# 2015-05-31       Customer Care Call          Edgewood     Washington
# 2015-05-31       Customer Care Call           Peabody  Massachusetts
#
#                  Zip code Filing on Behalf of Someone newStatus
# Date_month_year
# 2015-01-04          30312                          No    Closed
# 2015-01-04          19087                          No    Closed
# 2015-01-04          37067                          No    Closed
# 2015-01-04          31406                          No    Closed
# 2015-01-04          15642                          No    Closed
# 2015-01-04          60193                          No    Closed
# 2015-01-04          80401                          No    Closed
# 2015-01-04          35801                          No    Closed
# 2015-01-04          94560                          No    Closed
# 2015-01-04          95360                          No    Closed
# 2015-01-04          19128                          No    Closed
# 2015-01-04          19121                          No    Closed
# 2015-01-04          33426                          No    Closed
# 2015-01-04          60441                          No    Closed
# 2015-01-04          15301                          No    Closed
# 2015-01-04          15132                          No    Closed
# 2015-01-04          30083                          No    Closed
# 2015-01-04          60085                          No    Closed
# 2015-02-04          15222                          No    Closed
# 2015-02-04          15222                          No    Closed
# 2015-02-04          30024                          No    Closed
# 2015-02-04          19119                          No    Closed
# 2015-02-04          98012                          No    Closed
# 2015-02-04          37064                          No    Closed
# 2015-02-04          80110                          No    Closed
# 2015-02-04          95670                          No    Closed
# 2015-02-04          30269                          No    Closed
# 2015-02-04          30171                          No    Closed
# 2015-02-04          87507                          No    Closed
# 2015-02-04          60657                          No    Closed
# ...                   ...                         ...       ...
# 2015-06-30          95054                          No      Open
# 2015-06-30           8043                          No    Closed
# 2015-06-30          55116                          No    Closed
# 2015-06-30          32233                          No    Closed
# 2015-06-30          97217                          No    Closed
# 2015-06-30          30328                          No      Open
# 2015-06-30          30047                          No      Open
# 2015-06-30          30132                          No      Open
# 2015-06-30          84109                          No    Closed
# 2015-06-30          30093                          No      Open
# 2015-06-30          30019                          No    Closed
# 2015-06-30          60625                          No    Closed
# 2015-06-30          30342                          No      Open
# 2015-06-30          60608                          No    Closed
# 2015-06-30          31545                          No      Open
# 2015-06-30          71291                          No      Open
# 2015-06-30          38804                          No      Open
# 2015-06-30          30276                          No      Open
# 2015-06-30          80817                          No      Open
# 2015-06-30          19440                          No      Open
# 2015-05-31          77033                          No      Open
# 2015-05-31          30096                          No    Closed
# 2015-05-31          80910                          No    Closed
# 2015-05-31          30809                          No    Closed
# 2015-05-31          17011                          No    Closed
# 2015-05-31          97006                          No      Open
# 2015-05-31           8520                          No      Open
# 2015-05-31          30052                          No      Open
# 2015-05-31          98372                          No      Open
# 2015-05-31           1960                          No    Closed
#
# [2224 rows x 8 columns]

# %% [markdown]
# ### grouping state in terms of number of open and closed cases

# %%
stack=data.groupby(['State','newStatus']).size().unstack().fillna(0)

# %%
stack.head()
# Out:
# newStatus   Closed  Open
# State
# Alabama       17.0   9.0
# Arizona       14.0   6.0
# Arkansas       6.0   0.0
# California   159.0  61.0
# Colorado      58.0  22.0

# %% [markdown]
# ### plotting open and closed complaints wrt each state

# %%
stack.plot(kind='barh',stacked=True,figsize=(30,50))          # number of cases are stacked in terms of state

# %% [markdown]
# ### finding the state with maximum number of complaints

# %%
max_complaints=data.groupby(['State']).size().reset_index().rename({0:'counts'},axis=1)
max_complaints.head()
# Out:
#         State  counts
# 0     Alabama      26
# 1     Arizona      20
# 2    Arkansas       6
# 3  California     220
# 4    Colorado      80

# %%
max_complaints.max()
# Out:
# State     West Virginia
# counts              288
# dtype: object

# %% [markdown]
# ### each state with their respective pending percentage complaints

# %%
stack['% pending']= stack['Open']/(stack['Open']+stack['Closed'])
stack.head()
# Out:
# newStatus   Closed  Open  % pending
# State
# Alabama       17.0   9.0   0.346154
# Arizona       14.0   6.0   0.300000
# Arkansas       6.0   0.0   0.000000
# California   159.0  61.0   0.277273
# Colorado      58.0  22.0   0.275000

# %%
stack['% pending'].max(axis=0)
# Out:
# 0.5

# %% [markdown]
# ### state with maximum pending complaints percentage

# %%
stack.loc[stack['% pending'] == 0.5]
# Out:
# newStatus  Closed  Open  % pending
# State
# Kansas        1.0   1.0        0.5
